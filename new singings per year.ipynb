# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
new_singings = pd.read_csv("new_singings_by_year.csv")

# %%
plt = new_singings.plot(x='Year', y='Count', kind='bar', legend=False)
